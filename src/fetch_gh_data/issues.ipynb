# %%
import pandas as pd

df = pd.read_csv("DataDog_datadog-agent_issues.csv")

df.head()
# Out:
#    number                                              title   state  \
# 0   36975  Kubernetes CronJob with timeZone are detected ...    open
# 1   36938  [BUG] restart agent, k8s log file read from be...    open
# 2   36921  [BUG] Metric not being tagged when process che...    open
# 3   36789  [BUG] Obfuscating possible credit card under k...  closed
# 4   36780  [BUG] Single step instrumentation error openin...    open
#
#   state_reason            created_at            updated_at  \
# 0          NaN  2025-05-14T14:40:52Z  2025-05-14T14:43:12Z
# 1          NaN  2025-05-13T20:32:20Z  2025-05-13T20:59:08Z
# 2          NaN  2025-05-13T14:47:46Z  2025-05-13T21:00:07Z
# 3    completed  2025-05-08T13:23:27Z  2025-05-12T06:53:22Z
# 4          NaN  2025-05-08T04:45:00Z  2025-05-09T18:02:53Z
#
#               closed_at  comments                                      labels  \
# 0                   NaN         0                      ['team/container-app']
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   number                        32 non-null     int64
#  1   title                         32 non-null     object
#  2   state                         32 non-null     object
#  3   state_reason                  7 non-null      object
#  4   created_at                    32 non-null     object
#  5   updated_at                    32 non-null     object
#  6   closed_at                     7 non-null      object
#  7   comments                      32 non-null     int64
#  8   labels                        32 non-null     object
#  9   user                          32 non-null     object
#  10  assignee                      2 non-null      object
#  11  author_association            32 non-null     object
# ...

# %%
df["state"].value_counts()
# Out:
# state
# open      25
# closed     7
# Name: count, dtype: int64

# %%
df["state_reason"].value_counts()
# Out:
# state_reason
# completed    7
# Name: count, dtype: int64

# %%
df[["title", "url", "state", "state_reason"]].query(
    'state == "closed"'
)  # where state is closed
# Out:
#                                                 title  \
# 3   [BUG] Obfuscating possible credit card under k...
# 6                    Vulnerabilities in Agent v7.64.3
# 12  [BUG] Datadog on GKE Autopilot constantly repo...
# 14  [BUG] Aurora Autodiscovery extra_dbname doesn'...
# 15  [BUG] SQL Server Integration Errors on upgrade...
# 17  [BUG] IMDSv2 / AWS Fargate - Loop of warning l...
# 20                                [BUG] CVE-2025-0665
#
#                                                   url   state state_reason
# 3   https://github.com/DataDog/datadog-agent/issue...  closed    completed
# 6   https://github.com/DataDog/datadog-agent/issue...  closed    completed
# 12  https://github.com/DataDog/datadog-agent/issue...  closed    completed
# 14  https://github.com/DataDog/datadog-agent/issue...  closed    completed
# 15  https://github.com/DataDog/datadog-agent/issue...  closed    completed
# 17  https://github.com/DataDog/datadog-agent/issue...  closed    completed
# ...
